# %% [markdown]
# # Hirelytics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("HR_Data.csv")

# %%
df.head()
# Out:
#          ID  Gender   FTE   Emp Type Department                     Branch  \
# 0  EMP13653  MALE    1.00  Permanent       Beta                 Onboarding
# 1  EMP14030  FEMALE  1.00  Permanent       Beta                 Onboarding
# 2  EMP24533  FEMALE  1.00      Other       Beta                      Legal
# 3  EMP22630  FEMALE  1.00  Permanent      Gamma                 Web Design
# 4  EMP16847  FEMALE  0.53  Permanent       Zeta  Service Quality Assurance
#
#       Salary  Leave Balance Date of Join Date of Birth  Tenure  \
# 0   $75,315              23    15-Jun-22      6-Apr-65    3.92
# 1   $78,930              17    14-Jun-22      5-Dec-75    3.93
# 2  $100,130               9    27-Jun-22     23-Nov-19    3.89
# 3   $70,385              13    13-Jul-21     25-Sep-66    4.85
# 4   $58,175              10    11-Jul-22     11-Jul-86    3.85
#
#           Tenure Group     Age
# 0  4. 2 or more years.   61.15
# 1  4. 2 or more years.   50.48
# 2  4. 2 or more years.  106.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3890 entries, 0 to 3889
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             3890 non-null   object
#  1   Gender         3890 non-null   object
#  2   FTE            3890 non-null   float64
#  3   Emp Type       3890 non-null   object
#  4   Department     3890 non-null   object
#  5   Branch         3890 non-null   object
#  6   Salary         3890 non-null   object
#  7   Leave Balance  3890 non-null   int64
#  8   Date of Join   3890 non-null   object
#  9   Date of Birth  3890 non-null   object
#  10  Tenure         3890 non-null   float64
#  11  Tenure Group   3890 non-null   object
#  12  Age            3890 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 395.2+ KB

# %%
df.shape
# Out:
# (3890, 13)

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'FTE', 'Emp Type', 'Department', 'Branch', 'Salary',
#        'Leave Balance', 'Date of Join', 'Date of Birth', 'Tenure',
#        'Tenure Group', 'Age'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                object
# Gender            object
# FTE              float64
# Emp Type          object
# Department        object
# Branch            object
# Salary            object
# Leave Balance      int64
# Date of Join      object
# Date of Birth     object
# Tenure           float64
# Tenure Group      object
# Age              float64
# dtype: object
